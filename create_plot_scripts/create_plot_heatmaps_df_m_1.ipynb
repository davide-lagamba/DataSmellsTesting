# %%
#tutorial https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/
# https://stackoverflow.com/questions/52273543/creating-multiple-boxplots-on-the-same-graph-from-a-dictionary
# https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html
from time import sleep
import warnings
import requests
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from bs4 import BeautifulSoup
import os
# La directory viene cambiata puntando alla directory padre per raggiungere più facilmente i risultati
os.chdir("..")

# %% [markdown]
# F1 Score

# %%
models = ['ExtraTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier',
 'KNeighborsClassifier', 'DecisionTreeClassifier', 'GaussianNB',
 'ExtraTreesClassifier', 'LabelPropagation', 'RandomForestClassifier',
 'NuSVC', 'LabelSpreading', 'SVC', 'XGBClassifier',
 'QuadraticDiscriminantAnalysis', 'LGBMClassifier',
 'LinearDiscriminantAnalysis', 'CalibratedClassifierCV', 'DummyClassifier',
 'LinearSVC', 'SGDClassifier', 'RidgeClassifier', 'RidgeClassifierCV',
 'LogisticRegression', 'PassiveAggressiveClassifier', 'Perceptron',
 'NearestCentroid', 'BernoulliNB']

models = ['ExtraTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier',
 'KNeighborsClassifier', 'DecisionTreeClassifier', 'GaussianNB',
 'ExtraTreesClassifier', 'LabelPropagation', 'RandomForestClassifier']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")[0:9]

models_data_f1_score = models_data_f1_score.round(2)
models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_f1_score)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_f1_score[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of F1 Score averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [a]", pad =20)
plt.show()

# %%
models = ['NuSVC', 'LabelSpreading', 'SVC', 'XGBClassifier',
 'QuadraticDiscriminant\nAnalysis', 'LGBMClassifier',
 'LinearDiscriminant\nAnalysis', 'CalibratedClassifierCV', 'DummyClassifier']

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")[9:18]

models_data_f1_score = models_data_f1_score.round(2)
models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_f1_score)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_f1_score[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of F1 Score averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [b]", pad =20)
plt.show()

# %%
models = ['LinearSVC', 'SGDClassifier', 'RidgeClassifier', 'RidgeClassifierCV',
 'LogisticRegression', 'PassiveAggressive\nClassifier', 'Perceptron',
 'NearestCentroid', 'BernoulliNB']
models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")[18:27]

models_data_f1_score = models_data_f1_score.round(2)
models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_f1_score)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_f1_score[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of F1 Score averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [c]", pad =20)
plt.show()

# %% [markdown]
# Accuracy

# %%
models = ['ExtraTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier',
 'KNeighborsClassifier', 'DecisionTreeClassifier', 'GaussianNB',
 'ExtraTreesClassifier', 'LabelPropagation', 'RandomForestClassifier']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/accuracy.npy")[0:9]
models_data_accuracy = models_data_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [a]", pad =20)
plt.show()

# %%
models = ['NuSVC', 'LabelSpreading', 'SVC', 'XGBClassifier',
 'QuadraticDiscriminant\nAnalysis', 'LGBMClassifier',
 'LinearDiscriminant\nAnalysis', 'CalibratedClassifierCV', 'DummyClassifier']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/accuracy.npy")[9:18]
models_data_accuracy = models_data_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [b]", pad =20)
plt.show()

# %%
models = ['LinearSVC', 'SGDClassifier', 'RidgeClassifier', 'RidgeClassifierCV',
 'LogisticRegression', 'PassiveAggressive\nClassifier', 'Perceptron',
 'NearestCentroid', 'BernoulliNB']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/accuracy.npy")[18:27]
models_data_accuracy = models_data_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [c]", pad =20)
plt.show()

# %% [markdown]
# Balanced Accuracy

# %%
models = ['ExtraTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier',
 'KNeighborsClassifier', 'DecisionTreeClassifier', 'GaussianNB',
 'ExtraTreesClassifier', 'LabelPropagation', 'RandomForestClassifier']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_f1_score = models_data_f1_score.round(2)
models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")[0:9]
models_data_bal_accuracy = models_data_bal_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_bal_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_bal_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Balanced Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [a]", pad =20)
plt.show()

# %%
models = ['NuSVC', 'LabelSpreading', 'SVC', 'XGBClassifier',
 'QuadraticDiscriminant\nAnalysis', 'LGBMClassifier',
 'LinearDiscriminant\nAnalysis', 'CalibratedClassifierCV', 'DummyClassifier']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_f1_score = models_data_f1_score.round(2)
models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")[9:18]
models_data_bal_accuracy = models_data_bal_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_bal_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_bal_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Balanced Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [b]", pad =20)
plt.show()

# %%
models = ['LinearSVC', 'SGDClassifier', 'RidgeClassifier', 'RidgeClassifierCV',
 'LogisticRegression', 'PassiveAggressive\nClassifier', 'Perceptron',
 'NearestCentroid', 'BernoulliNB']

scenarios = ["Base", "Base + Synthetic data", "Base + Synthetic data (FP Dataset)", "Casing", "Missing Values", "Floating Point Number As String", "Suspect Sign"]

models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")

models_data_bal_accuracy = np.load("./outputComparisons/Models/Heatmaps_df_m_1/bal_accuracy.npy")[18:27]
models_data_bal_accuracy = models_data_bal_accuracy.round(2)
#models_data_f1_score = np.load("./outputComparisons/Models/Heatmaps_df_m_1/f1_score.npy")
models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")

fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_bal_accuracy)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_bal_accuracy[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Balanced Accuracy averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [c]", pad =20)
plt.show()

# %% [markdown]
# Time Taken

# %%
models = ['ExtraTreeClassifier', 'BaggingClassifier', 'AdaBoostClassifier',
 'KNeighborsClassifier', 'DecisionTreeClassifier', 'GaussianNB',
 'ExtraTreesClassifier', 'LabelPropagation', 'RandomForestClassifier']

models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")[0:9]
models_data_time = models_data_time.round(1)
fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_time)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_time[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Time Taken averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [a]", pad =20)
plt.show()

# %%
models = ['NuSVC', 'LabelSpreading', 'SVC', 'XGBClassifier',
 'QuadraticDiscriminant\nAnalysis', 'LGBMClassifier',
 'LinearDiscriminant\nAnalysis', 'CalibratedClassifierCV', 'DummyClassifier']

models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")[9:18]
models_data_time = models_data_time.round(1)
fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_time)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_time[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Time Taken averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [b]", pad =20)
plt.show()

# %%
models = ['LinearSVC', 'SGDClassifier', 'RidgeClassifier', 'RidgeClassifierCV',
 'LogisticRegression', 'PassiveAggressive\nClassifier', 'Perceptron',
 'NearestCentroid', 'BernoulliNB']

models_data_time = np.load("./outputComparisons/Models/Heatmaps_df_m_1/time.npy")[18:27]
models_data_time = models_data_time.round(1)
fig, heatmap = plt.subplots()
imshow = heatmap.imshow(models_data_time)
heatmap.set_xticks(np.arange(len(scenarios)), labels=scenarios)
heatmap.set_yticks(np.arange(len(models)), labels=models)
plt.setp(heatmap.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(len(models)):
    for j in range(len(scenarios)):
        text = heatmap.text(j, i, models_data_time[i, j],
                       ha="center", va="center", color="w")
        

heatmap.set_title("Heatmap of Time Taken averages of classification models, \ntrained on different types of \"Firefighter_Promotion_Exam_Scores\" \nwith categorical feature [c]", pad =20)
plt.show()

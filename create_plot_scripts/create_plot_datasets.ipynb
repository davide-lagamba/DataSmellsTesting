# %%
#tutorial https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/
# https://stackoverflow.com/questions/52273543/creating-multiple-boxplots-on-the-same-graph-from-a-dictionary
# https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html
from time import sleep
import warnings
import requests
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from bs4 import BeautifulSoup
import os
from scipy.stats import ks_2samp
from scipy import stats
# La directory viene cambiata puntando alla directory padre per raggiungere più facilmente i risultati
os.chdir("..")

# %% [markdown]
# df_l_1 : kdd-census

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_1/df_l_1.csv", index_col= False)
df_plot_base_synthetic= pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_1.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_1/df_l_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["F1 Score"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["F1 Score"]), "Casing": list(df_plot_casing["F1 Score"]), "Missing Values": list(df_plot_missingvalues["F1 Score"]), "Suspect Sign": list(df_plot_suspectsign["F1 Score"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("F1 Score of the classification models trained \non the different types of \"kdd-census\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("F1 Score")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("F1 Score - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
# Out:
# F1 Score - Differences using Kolmogorov-Smirnov Test

# %%
print(stats.shapiro(df_plot_base["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic["F1 Score"]))
print(stats.shapiro(df_plot_casing["F1 Score"]))
print(stats.shapiro(df_plot_suspectsign["F1 Score"]))
print(stats.shapiro(df_plot_missingvalues["F1 Score"]))
# Out:
# ShapiroResult(statistic=0.5967925786972046, pvalue=2.71602829116091e-07)
# ShapiroResult(statistic=0.5865004062652588, pvalue=2.0739558692639548e-07)
# ShapiroResult(statistic=0.5591533780097961, pvalue=1.0331067556990092e-07)
# ShapiroResult(statistic=0.5748025178909302, pvalue=1.534084930199242e-07)
# ShapiroResult(statistic=0.6271603107452393, pvalue=6.175525868457044e-07)

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_1/df_l_1.csv", index_col= False)
df_plot_base_synthetic= pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_1.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_1/df_l_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Accuracy"]), "Casing": list(df_plot_casing["Accuracy"]), "Missing Values": list(df_plot_missingvalues["Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Accuracy of the classification models trained \non the different types of \"kdd-census\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
# Out:
# Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_1/df_l_1.csv", index_col= False)
df_plot_base_synthetic= pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_1.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_1/df_l_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Balanced Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Balanced Accuracy"]), "Casing": list(df_plot_casing["Balanced Accuracy"]), "Missing Values": list(df_plot_missingvalues["Balanced Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Balanced Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Balanced Accuracy of the classification models trained \non the different types of \"kdd-census\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Balanced Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Balanced Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
# Out:
# Balanced Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_1/df_l_1.csv", index_col= False)
df_plot_base_synthetic= pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_1.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_1/df_l_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_1/df_l_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Time Taken"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Time Taken"]), "Casing": list(df_plot_casing["Time Taken"]), "Missing Values": list(df_plot_missingvalues["Time Taken"]), "Suspect Sign": list(df_plot_suspectsign["Time Taken"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Time Taken of the classification models trained \non the different types of \"kdd-census\" dataset \n(detail between 0 and 8 seconds)")
box.set_xlabel("Version of dataset")
box.set_ylabel("Time Taken")
box.set_ylim(0, 8)
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Time Taken - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
# Out:
# Time Taken - Differences using Kolmogorov-Smirnov Test

# %% [markdown]
# df_l_2: diabetic_data

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_2/df_l_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_2.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_2/df_l_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["F1 Score"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["F1 Score"]), "Casing": list(df_plot_casing["F1 Score"]), "Missing Values": list(df_plot_missingvalues["F1 Score"]), "Suspect Sign": list(df_plot_suspectsign["F1 Score"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("F1 Score of the classification models trained \non the different types of \"diabetic_data\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("F1 Score")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("F1 Score - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
# Out:
# F1 Score - Differences using Kolmogorov-Smirnov Test

# %%
print(stats.shapiro(df_plot_base["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic["F1 Score"]))
print(stats.shapiro(df_plot_casing["F1 Score"]))
print(stats.shapiro(df_plot_suspectsign["F1 Score"]))
print(stats.shapiro(df_plot_missingvalues["F1 Score"]))
#non tutte le distribuzioni possono essere considerate normali
# Out:
# ShapiroResult(statistic=0.5147480964660645, pvalue=3.523793523640961e-08)
# ShapiroResult(statistic=0.9511273503303528, pvalue=0.24639523029327393)
# ShapiroResult(statistic=0.9250329732894897, pvalue=0.059069424867630005)
# ShapiroResult(statistic=0.9389544725418091, pvalue=0.12680011987686157)
# ShapiroResult(statistic=0.9331474900245667, pvalue=0.09211137145757675)

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_2/df_l_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_2.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_2/df_l_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Accuracy"]), "Casing": list(df_plot_casing["Accuracy"]), "Missing Values": list(df_plot_missingvalues["Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Accuracy of the classification models trained \non the different types of \"diabetic_data\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
# Out:
# Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_2/df_l_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_2.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_2/df_l_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Balanced Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Balanced Accuracy"]), "Casing": list(df_plot_casing["Balanced Accuracy"]), "Missing Values": list(df_plot_missingvalues["Balanced Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Balanced Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Balanced Accuracy of the classification models trained \non the different types of \"diabetic_data\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Balanced Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Balanced Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
# Out:
# Balanced Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_2/df_l_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_2.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_l_2/df_l_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_l_2/df_l_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Time Taken"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Time Taken"]), "Casing": list(df_plot_casing["Time Taken"]), "Missing Values": list(df_plot_missingvalues["Time Taken"]), "Suspect Sign": list(df_plot_suspectsign["Time Taken"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Time Taken of the classification models trained \non the different types of \"diabetic_data\" dataset \n(detail between 0 and 10 seconds)")
box.set_xlabel("Version of dataset")
box.set_ylabel("Time Taken")
box.set_ylim(0, 10)
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing'),
#  Text(4, 0, 'Missing Values'),
#  Text(5, 0, 'Suspect Sign')]

# %%
print("Time Taken - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
# Out:
# Time Taken - Differences using Kolmogorov-Smirnov Test

# %% [markdown]
# df_l_3: nursery

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_3/df_l_3.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_3.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_3/df_l_3_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["F1 Score"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["F1 Score"]), "Casing": list(df_plot_casing["F1 Score"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("F1 Score of the classification models trained \non the different types of \"nursery\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("F1 Score")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing')]

# %%
print(stats.shapiro(df_plot_base["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic["F1 Score"]))
print(stats.shapiro(df_plot_casing["F1 Score"]))
# Out:
# ShapiroResult(statistic=0.6738457083702087, pvalue=1.7122711142292246e-06)
# ShapiroResult(statistic=0.6929962635040283, pvalue=3.1027734621602576e-06)
# ShapiroResult(statistic=0.7458432912826538, pvalue=1.8042797819362022e-05)

# %%
print("F1 Score - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
# Out:
# F1 Score - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_3/df_l_3.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_3.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_3/df_l_3_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Accuracy"]), "Casing": list(df_plot_casing["Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Accuracy of the classification models trained \non the different types of \"nursery\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing')]

# %%
print("Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
# Out:
# Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_3/df_l_3.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_3.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_3/df_l_3_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Balanced Accuracy"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Balanced Accuracy"]), "Casing": list(df_plot_casing["Balanced Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Balanced Accuracy of the classification models trained \non the different types of \"nursery\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Balanced Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing')]

# %%
print("Balanced Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
# Out:
# Balanced Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_l_3/df_l_3.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_l_3.csv", index_col= False)
df_plot_casing= pd.read_csv("./outputLazyPredict/Casing/df_l_3/df_l_3_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Time Taken"]), "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Time Taken"]), "Casing": list(df_plot_casing["Time Taken"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Time Taken of the classification models trained \non the different types of \"nursery\" dataset \n(detail between 0 and 2 seconds)")
box.set_xlabel("Version of dataset")
box.set_ylabel("Time Taken")
box.set_ylim(0, 2)
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Casing')]

# %%
print("Time Taken - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
# Out:
# Time Taken - Differences using Kolmogorov-Smirnov Test

# %% [markdown]
# df_m_1: Firefighter_Promotion_Exam_Scores

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_1/df_m_1.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_base_synthetic_fp = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1_FP.csv", index_col= False)
df_plot_floatingpoint = pd.read_csv("./outputLazyPredict/FloatingPointNumberAsString/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_casing = pd.read_csv("./outputLazyPredict/Casing/df_m_1/df_m_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["F1 Score"]), "Base + \nSynthetic \ndata \n(No DS \ninjected)": list(df_plot_base_synthetic["F1 Score"]), "Missing \nValues": list(df_plot_missingvalues["F1 Score"]), "Suspect\nSign": list(df_plot_suspectsign["F1 Score"]), "Base +\n Synthetic \ndata \n(FP size)\n(No DS \ninjected)": list(df_plot_base_synthetic_fp["F1 Score"]), "Floating \nPoint \nNumber\nAs String": list(df_plot_floatingpoint["F1 Score"]), "Casing": list(df_plot_casing["F1 Score"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("F1 Score of the classification models trained \non the different types of \"Firefighter_Promotion_Exam_Scores\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("F1 Score")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base + \nSynthetic \ndata \n(No DS \ninjected)'),
#  Text(3, 0, 'Missing \nValues'),
#  Text(4, 0, 'Suspect\nSign'),
#  Text(5, 0, 'Base +\n Synthetic \ndata \n(FP size)\n(No DS \ninjected)'),
#  Text(6, 0, 'Floating \nPoint \nNumber\nAs String'),
#  Text(7, 0, 'Casing')]

# %%
print(stats.shapiro(df_plot_base["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic_fp["F1 Score"]))
print(stats.shapiro(df_plot_casing["F1 Score"]))
print(stats.shapiro(df_plot_suspectsign["F1 Score"]))
print(stats.shapiro(df_plot_missingvalues["F1 Score"]))
print(stats.shapiro(df_plot_floatingpoint["F1 Score"]))
# Out:
# ShapiroResult(statistic=0.4210662245750427, pvalue=2.9025271075511228e-09)
# ShapiroResult(statistic=0.5169798135757446, pvalue=2.5155445726454673e-08)
# ShapiroResult(statistic=0.43845778703689575, pvalue=4.2150634094184625e-09)
# ShapiroResult(statistic=0.4574444890022278, pvalue=6.390481921414448e-09)
# ShapiroResult(statistic=0.5274891257286072, pvalue=3.240036505758326e-08)
# ShapiroResult(statistic=0.3878680467605591, pvalue=1.4530294745185302e-09)
# ShapiroResult(statistic=0.5009491443634033, pvalue=1.7214743408544564e-08)

# %%
print("F1 Score - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_casing["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic_fp["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic (FP size) - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic_fp["F1 Score"]).pvalue)    
if(ks_2samp(df_plot_base_synthetic_fp["F1 Score"], df_plot_floatingpoint["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic (FP size) vs Floating Point Number As String - pvalue: ", ks_2samp(df_plot_base_synthetic_fp["F1 Score"], df_plot_floatingpoint["F1 Score"]).pvalue) 
if(ks_2samp(df_plot_base["F1 Score"], df_plot_floatingpoint["F1 Score"]).pvalue < 0.05):
    print("Base vs Floating Point Number As String: ", ks_2samp(df_plot_base["F1 Score"], df_plot_floatingpoint["F1 Score"]))    
    print("Base:",df_plot_base["F1 Score"].describe())    
    print("Floating Point Number As String:",df_plot_floatingpoint["F1 Score"].describe())
# Out:
# F1 Score - Differences using Kolmogorov-Smirnov Test
# Base vs Floating Point Number As String:  KstestResult(statistic=0.37037037037037035, pvalue=0.04843826268679447, statistic_location=0.9582608695652174, statistic_sign=-1)
# Base: count    27.000000
# mean      0.936787
# std       0.164428
# min       0.333333
# 25%       0.958261
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: F1 Score, dtype: float64
# Floating Point Number As String: count    27.000000
# mean      0.922409
# std       0.126074
# min       0.333333
# 25%       0.916084
# 50%       0.958261
# 75%       0.979130
# max       1.000000
# Name: F1 Score, dtype: float64
# C:\Users\Utente\AppData\Local\Temp\ipykernel_23068\213778708.py:16: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic_fp["F1 Score"]).pvalue < 0.05):

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_1/df_m_1.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_base_synthetic_fp = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1_FP.csv", index_col= False)
df_plot_floatingpoint = pd.read_csv("./outputLazyPredict/FloatingPointNumberAsString/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_casing = pd.read_csv("./outputLazyPredict/Casing/df_m_1/df_m_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Accuracy"]), "Base + \nSynthetic \ndata \n(No DS \ninjected)": list(df_plot_base_synthetic["Accuracy"]), "Missing \nValues": list(df_plot_missingvalues["Accuracy"]), "Suspect\nSign": list(df_plot_suspectsign["Accuracy"]), "Base +\n Synthetic \ndata \n(FP size)\n(No DS \ninjected)": list(df_plot_base_synthetic_fp["Accuracy"]), "Floating \nPoint \nNumber\nAs String": list(df_plot_floatingpoint["Accuracy"]), "Casing": list(df_plot_casing["Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Accuracy of the classification models trained \non the different types of \"Firefighter_Promotion_Exam_Scores\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base + \nSynthetic \ndata \n(No DS \ninjected)'),
#  Text(3, 0, 'Missing \nValues'),
#  Text(4, 0, 'Suspect\nSign'),
#  Text(5, 0, 'Base +\n Synthetic \ndata \n(FP size)\n(No DS \ninjected)'),
#  Text(6, 0, 'Floating \nPoint \nNumber\nAs String'),
#  Text(7, 0, 'Casing')]

# %%
print("Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_casing["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic_fp["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic (FP size) - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic_fp["Accuracy"]).pvalue)    
if(ks_2samp(df_plot_base_synthetic_fp["Accuracy"], df_plot_floatingpoint["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic (FP size) vs Floating Point Number As String - pvalue: ", ks_2samp(df_plot_base_synthetic_fp["Accuracy"], df_plot_floatingpoint["Accuracy"]).pvalue) 
if(ks_2samp(df_plot_base["Accuracy"], df_plot_floatingpoint["Accuracy"]).pvalue < 0.05):
    print("Base vs Floating Point Number As String: ", ks_2samp(df_plot_base["Accuracy"], df_plot_floatingpoint["Accuracy"]))          
    print("Base:", df_plot_base["Accuracy"].describe())    
    print("Floating Point Number As String:", df_plot_floatingpoint["Accuracy"].describe())
# Out:
# Accuracy - Differences using Kolmogorov-Smirnov Test
# Base vs Floating Point Number As String:  KstestResult(statistic=0.37037037037037035, pvalue=0.04843826268679447, statistic_location=0.9583333333333334, statistic_sign=-1)
# Base: count    27.000000
# mean      0.947531
# std       0.126377
# min       0.500000
# 25%       0.958333
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: Accuracy, dtype: float64
# Floating Point Number As String: count    27.000000
# mean      0.929012
# std       0.096559
# min       0.500000
# 25%       0.916667
# 50%       0.958333
# 75%       0.979167
# max       1.000000
# Name: Accuracy, dtype: float64
# C:\Users\Utente\AppData\Local\Temp\ipykernel_23068\1918842843.py:16: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic_fp["Accuracy"]).pvalue < 0.05):

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_1/df_m_1.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_base_synthetic_fp = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1_FP.csv", index_col= False)
df_plot_floatingpoint = pd.read_csv("./outputLazyPredict/FloatingPointNumberAsString/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_casing = pd.read_csv("./outputLazyPredict/Casing/df_m_1/df_m_1_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Balanced Accuracy"]), "Base + \nSynthetic \ndata \n(No DS \ninjected)": list(df_plot_base_synthetic["Balanced Accuracy"]), "Missing \nValues": list(df_plot_missingvalues["Balanced Accuracy"]), "Suspect\nSign": list(df_plot_suspectsign["Balanced Accuracy"]), "Base + \nSynthetic \ndata \n(FP size)\n(No DS \ninjected)": list(df_plot_base_synthetic_fp["Balanced Accuracy"]), "Floating \nPoint \nNumber\nAs String": list(df_plot_floatingpoint["Balanced Accuracy"]), "Casing": list(df_plot_casing["Balanced Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Balanced Accuracy of the classification models trained \non the different types of \"Firefighter_Promotion_Exam_Scores\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Balanced Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base + \nSynthetic \ndata \n(No DS \ninjected)'),
#  Text(3, 0, 'Missing \nValues'),
#  Text(4, 0, 'Suspect\nSign'),
#  Text(5, 0, 'Base + \nSynthetic \ndata \n(FP size)\n(No DS \ninjected)'),
#  Text(6, 0, 'Floating \nPoint \nNumber\nAs String'),
#  Text(7, 0, 'Casing')]

# %%
print("Balanced Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_casing["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic_fp["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic (FP size) - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic_fp["Balanced Accuracy"]).pvalue)    
if(ks_2samp(df_plot_base_synthetic_fp["Balanced Accuracy"], df_plot_floatingpoint["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic (FP size) vs Floating Point Number As String - pvalue: ", ks_2samp(df_plot_base_synthetic_fp["Balanced Accuracy"], df_plot_floatingpoint["Balanced Accuracy"]).pvalue) 
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_floatingpoint["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Floating Point Number As String: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_floatingpoint["Balanced Accuracy"]))      
    print("Base: ",df_plot_base["Balanced Accuracy"].describe())      
    print("Floating Point Number As String: ",df_plot_floatingpoint["Balanced Accuracy"].describe())
# Out:
# Balanced Accuracy - Differences using Kolmogorov-Smirnov Test
# Base vs Floating Point Number As String:  KstestResult(statistic=0.37037037037037035, pvalue=0.04843826268679447, statistic_location=0.9583333333333331, statistic_sign=-1)
# Base:  count    27.000000
# mean      0.947531
# std       0.126377
# min       0.500000
# 25%       0.958333
# 50%       1.000000
# 75%       1.000000
# max       1.000000
# Name: Balanced Accuracy, dtype: float64
# Floating Point Number As String:  count    27.000000
# mean      0.929012
# std       0.096559
# min       0.500000
# 25%       0.916667
# 50%       0.958333
# 75%       0.979167
# max       1.000000
# Name: Balanced Accuracy, dtype: float64
# C:\Users\Utente\AppData\Local\Temp\ipykernel_23068\2927546194.py:16: RuntimeWarning: ks_2samp: Exact calculation unsuccessful. Switching to method=asymp.
#   if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic_fp["Balanced Accuracy"]).pvalue < 0.05):

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_1/df_m_1.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_base_synthetic_fp = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_1_FP.csv", index_col= False)
df_plot_floatingpoint = pd.read_csv("./outputLazyPredict/FloatingPointNumberAsString/df_m_1/df_m_1_1.csv", index_col= False)
df_plot_casing = pd.read_csv("./outputLazyPredict/Casing/df_m_1/df_m_1_1.csv", index_col= False)



dict_df = {"Base" : list(df_plot_base["Time Taken"]), "Base + \nSynthetic \ndata \n(No DS \ninjected)": list(df_plot_base_synthetic["Time Taken"]), "Missing \nValues": list(df_plot_missingvalues["Time Taken"]), "Suspect\nSign": list(df_plot_suspectsign["Time Taken"]), "Base + \nSynthetic \ndata \n(FP size)\n(No DS \ninjected)": list(df_plot_base_synthetic_fp["Time Taken"]), "Floating \nPoint \nNumber\nAs String": list(df_plot_floatingpoint["Time Taken"]), "Casing": list(df_plot_casing["Time Taken"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Time Taken of the classification models trained \non the different types of \"Firefighter_Promotion_Exam_Scores\" dataset \n(detail between 0 and 0.04 seconds)")
box.set_xlabel("Version of dataset")
box.set_ylabel("Time Taken")
box.set_ylim(0, 0.04)
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base + \nSynthetic \ndata \n(No DS \ninjected)'),
#  Text(3, 0, 'Missing \nValues'),
#  Text(4, 0, 'Suspect\nSign'),
#  Text(5, 0, 'Base + \nSynthetic \ndata \n(FP size)\n(No DS \ninjected)'),
#  Text(6, 0, 'Floating \nPoint \nNumber\nAs String'),
#  Text(7, 0, 'Casing')]

# %%
print("Time Taken - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base vs Casing - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base vs Suspect Sign: ", ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]))
    print("Base: ",df_plot_base["Time Taken"].describe())      
    print("Suspect Sign: ",df_plot_suspectsign["Time Taken"].describe())    
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Casing - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_casing["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]))
    print("Base+Synthetic: ",df_plot_base_synthetic["Time Taken"].describe())      
    print("Suspect Sign: ",df_plot_suspectsign["Time Taken"].describe())  
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic_fp["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic (FP size) - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic_fp["Time Taken"]).pvalue)    
if(ks_2samp(df_plot_base_synthetic_fp["Time Taken"], df_plot_floatingpoint["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic (FP size) vs Floating Point Number As String - pvalue: ", ks_2samp(df_plot_base_synthetic_fp["Time Taken"], df_plot_floatingpoint["Time Taken"]).pvalue) 
if(ks_2samp(df_plot_base["Time Taken"], df_plot_floatingpoint["Time Taken"]).pvalue < 0.05):
    print("Base vs Floating Point Number As String: ", ks_2samp(df_plot_base["Time Taken"], df_plot_floatingpoint["Time Taken"]))
    print("Base: ",df_plot_base["Time Taken"].describe())      
    print("Floating Point Number As String: ",df_plot_floatingpoint["Time Taken"].describe())
# Out:
# Time Taken - Differences using Kolmogorov-Smirnov Test
# Base vs Suspect Sign:  KstestResult(statistic=0.5925925925925926, pvalue=9.83316187642921e-05, statistic_location=0.0121443271636962, statistic_sign=1)
# Base:  count    27.000000
# mean      0.024877
# std       0.030136
# min       0.010069
# 25%       0.011134
# 50%       0.011923
# 75%       0.014123
# max       0.121933
# Name: Time Taken, dtype: float64
# Suspect Sign:  count    27.000000
# mean      0.033479
# std       0.040257
# min       0.012165
# 25%       0.012968
# 50%       0.013499
# 75%       0.024502
# max       0.147115
# Name: Time Taken, dtype: float64
# Base+Synthetic vs Suspect Sign:  KstestResult(statistic=0.37037037037037035, pvalue=0.04843826268679447, statistic_location=0.0120699405670166, statistic_sign=1)
# Base+Synthetic:  count    27.000000
# mean      0.031703
# std       0.038346
# min       0.010358
# 25%       0.011866
# 50%       0.012710
# 75%       0.022380
# max       0.129784
# Name: Time Taken, dtype: float64
# Suspect Sign:  count    27.000000
# mean      0.033479
# std       0.040257
# min       0.012165
# 25%       0.012968
# 50%       0.013499
# 75%       0.024502
# max       0.147115
# Name: Time Taken, dtype: float64
# Base vs Floating Point Number As String:  KstestResult(statistic=0.4074074074074074, pvalue=0.02166982723648196, statistic_location=0.0121443271636962, statistic_sign=1)
# Base:  count    27.000000
# mean      0.024877
# std       0.030136
# min       0.010069
# 25%       0.011134
# 50%       0.011923
# 75%       0.014123
# max       0.121933
# Name: Time Taken, dtype: float64
# Floating Point Number As String:  count    27.000000
# mean      0.045616
# std       0.085749
# min       0.011176
# 25%       0.012470
# 50%       0.013069
# 75%       0.023009
# max       0.427336
# Name: Time Taken, dtype: float64

# %% [markdown]
# df_m_2: tae

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_2/df_m_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_2.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_2/df_m_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_2/df_m_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["F1 Score"]),  "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["F1 Score"]), "Missing Values": list(df_plot_missingvalues["F1 Score"]), "Suspect Sign": list(df_plot_suspectsign["F1 Score"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("F1 Score of the classification models trained \non the different types of \"tae\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("F1 Score")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Missing Values'),
#  Text(4, 0, 'Suspect Sign')]

# %%
print(stats.shapiro(df_plot_base["F1 Score"]))
print(stats.shapiro(df_plot_base_synthetic["F1 Score"]))
print(stats.shapiro(df_plot_suspectsign["F1 Score"]))
print(stats.shapiro(df_plot_missingvalues["F1 Score"]))
# Out:
# ShapiroResult(statistic=0.8364897966384888, pvalue=0.0007868563407100737)
# ShapiroResult(statistic=0.8812503814697266, pvalue=0.006118264514952898)
# ShapiroResult(statistic=0.8652771711349487, pvalue=0.002855964470654726)
# ShapiroResult(statistic=0.8792088031768799, pvalue=0.005539738107472658)

# %%
print("F1 Score - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_base_synthetic["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_missingvalues["F1 Score"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["F1 Score"], df_plot_suspectsign["F1 Score"]).pvalue)
# Out:
# F1 Score - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_2/df_m_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_2.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_2/df_m_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_2/df_m_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Accuracy"]),  "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Accuracy"]), "Missing Values": list(df_plot_missingvalues["Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Accuracy of the classification models trained \non the different types of \"tae\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Missing Values'),
#  Text(4, 0, 'Suspect Sign')]

# %%
print("Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_base_synthetic["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_missingvalues["Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Accuracy"], df_plot_suspectsign["Accuracy"]).pvalue)
# Out:
# Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_2/df_m_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_2.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_2/df_m_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_2/df_m_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Balanced Accuracy"]),  "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Balanced Accuracy"]), "Missing Values": list(df_plot_missingvalues["Balanced Accuracy"]), "Suspect Sign": list(df_plot_suspectsign["Balanced Accuracy"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Balanced Accuracy of the classification models trained \non the different types of \"tae\" dataset")
box.set_xlabel("Version of dataset")
box.set_ylabel("Balanced Accuracy")
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Missing Values'),
#  Text(4, 0, 'Suspect Sign')]

# %%
print("Balanced Accuracy - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_base_synthetic["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_missingvalues["Balanced Accuracy"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Balanced Accuracy"], df_plot_suspectsign["Balanced Accuracy"]).pvalue)
# Out:
# Balanced Accuracy - Differences using Kolmogorov-Smirnov Test

# %%
df_plot_base = pd.read_csv("./outputLazyPredict/Base/df_m_2/df_m_2.csv", index_col= False)
df_plot_base_synthetic = pd.read_csv("./outputLazyPredict/BaseSynthetic/df_m_2.csv", index_col= False)
df_plot_missingvalues= pd.read_csv("./outputLazyPredict/MissingValues/df_m_2/df_m_2_1.csv", index_col= False)
df_plot_suspectsign = pd.read_csv("./outputLazyPredict/SuspectSign/df_m_2/df_m_2_1.csv", index_col= False)


dict_df = {"Base" : list(df_plot_base["Time Taken"]),  "Base \n+ Synthetic data \n(No DS injected)": list(df_plot_base_synthetic["Time Taken"]), "Missing Values": list(df_plot_missingvalues["Time Taken"]), "Suspect Sign": list(df_plot_suspectsign["Time Taken"])}

_, box = plt.subplots()
box.boxplot(dict_df.values(), 1)
box.set_title("Time Taken of the classification models trained \non the different types of \"tae\" dataset \n(detail between 0 and 0.03 seconds)")
box.set_xlabel("Version of dataset")
box.set_ylabel("Time Taken")
box.set_ylim(0, 0.03)
box.set_xticklabels(dict_df.keys())
# Out:
# [Text(1, 0, 'Base'),
#  Text(2, 0, 'Base \n+ Synthetic data \n(No DS injected)'),
#  Text(3, 0, 'Missing Values'),
#  Text(4, 0, 'Suspect Sign')]

# %%
print("Time Taken - Differences using Kolmogorov-Smirnov Test")
if(ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue < 0.05):
    print("Base vs Base+Synthetic - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_base_synthetic["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base vs Missing Values - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Missing Values: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_missingvalues["Time Taken"]))
    print("Base+Synthetic: ",df_plot_base_synthetic["Time Taken"].describe())      
    print("Missing Values: ",df_plot_floatingpoint["Time Taken"].describe())    
if(ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue < 0.05):
    print("Base+Synthetic vs Suspect Sign - pvalue: ", ks_2samp(df_plot_base_synthetic["Time Taken"], df_plot_suspectsign["Time Taken"]).pvalue)
# Out:
# Time Taken - Differences using Kolmogorov-Smirnov Test
# Base+Synthetic vs Missing Values:  KstestResult(statistic=0.4230769230769231, pvalue=0.018073053688695113, statistic_location=0.0119154453277587, statistic_sign=1)
# Base+Synthetic:  count    26.000000
# mean      0.032989
# std       0.050880
# min       0.010554
# 25%       0.010979
# 50%       0.011576
# 75%       0.013135
# max       0.223869
# Name: Time Taken, dtype: float64
# Missing Values:  count    27.000000
# mean      0.045616
# std       0.085749
# min       0.011176
# 25%       0.012470
# 50%       0.013069
# 75%       0.023009
# max       0.427336
# Name: Time Taken, dtype: float64

# %%
#tutorial https://medium.com/omics-diary/how-to-use-the-lazy-predict-library-to-select-the-best-machine-learning-model-65378bf4568e
# !pip install lazypredict
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost->lazypredict) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)

# %%
df_l_1_1_path = "./cleaned_datasets/df_l_1.csv"
df_l_2_1_path = "./cleaned_datasets/df_l_2.csv"
df_m_1_1_path = "./cleaned_datasets/df_m_1.csv"
df_m_2_1_path = "./cleaned_datasets/df_m_2.csv"
df_l_1_1 = pd.read_csv(df_l_1_1_path, index_col=False)
df_l_2_1 = pd.read_csv(df_l_2_1_path, index_col=False)
df_m_1_1 = pd.read_csv(df_m_1_1_path, index_col=False)
df_m_2_1 = pd.read_csv(df_m_2_1_path, index_col=False)

# %%
# !mkdir "outputLazyPredict"
# !mkdir "outputLazyPredict/SuspectSign"
# !mkdir "outputLazyPredict/SuspectSign/df_l_1"
# !mkdir "outputLazyPredict/SuspectSign/df_l_2"
# !mkdir "outputLazyPredict/SuspectSign/df_m_1"
# !mkdir "outputLazyPredict/SuspectSign/df_m_2"

output_path_l_1_1 = "outputLazyPredict/SuspectSign/df_l_1/df_l_1_1.csv"
output_path_l_2_1 = "outputLazyPredict/SuspectSign/df_l_2/df_l_2_1.csv"
output_path_m_1_1 = "outputLazyPredict/SuspectSign/df_m_1/df_m_1_1.csv"
output_path_m_2_1 = "outputLazyPredict/SuspectSign/df_m_2/df_m_2_1.csv"
# Out:
# mkdir: cannot create directory ‘outputLazyPredict’: File exists
# mkdir: cannot create directory ‘outputLazyPredict/SuspectSign’: File exists
# mkdir: cannot create directory ‘outputLazyPredict/SuspectSign/df_l_1’: File exists
# mkdir: cannot create directory ‘outputLazyPredict/SuspectSign/df_l_2’: File exists
# mkdir: cannot create directory ‘outputLazyPredict/SuspectSign/df_m_1’: File exists
# mkdir: cannot create directory ‘outputLazyPredict/SuspectSign/df_m_2’: File exists

# %%
ds_df_l_1_1_path = "./outputDSInjection/SuspectSign/df_l_1_1.csv"
ds_df_l_2_1_path = "./outputDSInjection/SuspectSign/df_l_2_1.csv"
ds_df_m_1_1_path = "./outputDSInjection/SuspectSign/df_m_1_1.csv"
ds_df_m_2_1_path = "./outputDSInjection/SuspectSign/df_m_2_1.csv"
ds_df_l_1_1 = pd.read_csv(ds_df_l_1_1_path, index_col=False)
#Viene utilizzata la seconda feature numerica più importante (discharge_disposition_id) perché la prima (number_inpatient) ha maggiormente 0 per
#per cui non si può manifestare lo smell generando dati realistici
ds_df_l_2_1 = pd.read_csv(ds_df_l_2_1_path, index_col=False)
ds_df_m_1_1 = pd.read_csv(ds_df_m_1_1_path, index_col=False)
ds_df_m_2_1 = pd.read_csv(ds_df_m_2_1_path, index_col=False)

# %%
x1 =  df_l_1_1.drop('income_level', axis=1)
ds_x1 = ds_df_l_1_1.drop('income_level', axis=1)
y1 = df_l_1_1['income_level']
ds_y1 = ds_df_l_1_1['income_level']
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state =42)
x1_train = pd.concat([x1_train, ds_x1])
y1_train = pd.concat([y1_train, ds_y1])

x2 =  df_l_2_1.drop(columns=['readmitted'])
ds_x2 = ds_df_l_2_1.drop('readmitted', axis=1)
y2 = df_l_2_1['readmitted']
ds_y2 = ds_df_l_2_1['readmitted']
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2, random_state =42)
x2_train = pd.concat([x2_train, ds_x2])
y2_train = pd.concat([y2_train, ds_y2])

x4 =  df_m_1_1.drop(columns=['promotion'])
ds_x4 = ds_df_m_1_1.drop('promotion', axis=1)
y4 = df_m_1_1['promotion']
ds_y4 = ds_df_m_1_1['promotion']
x4_train, x4_test, y4_train, y4_test = train_test_split(x4, y4, test_size=0.2, random_state =42)
x4_train = pd.concat([x4_train, ds_x4])
y4_train = pd.concat([y4_train, ds_y4])

x5 =  df_m_2_1.drop(columns=['Class_attribute'])
ds_x5 = ds_df_m_2_1.drop('Class_attribute', axis=1)
y5 = df_m_2_1['Class_attribute']
ds_y5 = ds_df_m_2_1['Class_attribute']
x5_train, x5_test, y5_train, y5_test = train_test_split(x5, y5, test_size=0.2, random_state =42)
x5_train = pd.concat([x5_train, ds_x5])
y5_train = pd.concat([y5_train, ds_y5])

categorical_x_train_l_1_1 = x1_train.select_dtypes(include="object")
for i in categorical_x_train_l_1_1:
  x1_train[i] = pd.factorize(x1_train[i])[0]
categorical_x_test_l_1_1 = x1_test.select_dtypes(include="object")
for i in categorical_x_test_l_1_1:
  x1_test[i] = pd.factorize(x1_test[i])[0]
if(y1_train.dtype == 'object'):
  y1_train, _ = pd.factorize(y1_train)
if(y1_test.dtype == 'object'):
  y1_test, _ = pd.factorize(y1_test)


categorical_x_train_l_2_1 = x2_train.select_dtypes(include="object")
for i in categorical_x_train_l_2_1:
  x2_train[i] = pd.factorize(x2_train[i])[0]
categorical_x_test_l_2_1 = x2_test.select_dtypes(include="object")
for i in categorical_x_test_l_2_1:
  x2_test[i] = pd.factorize(x2_test[i])[0]
if(y2_train.dtype == 'object'):
  y2_train, _ = pd.factorize(y2_train)
if(y2_test.dtype == 'object'):
  y2_test, _ = pd.factorize(y2_test)



categorical_x_train_m_1_1 = x4_train.select_dtypes(include="object")
for i in categorical_x_train_m_1_1:
  x4_train[i] = pd.factorize(x4_train[i])[0]
categorical_x_test_m_1_1 = x4_test.select_dtypes(include="object")
for i in categorical_x_test_m_1_1:
  x4_test[i] = pd.factorize(x4_test[i])[0]
if(y4_train.dtype == 'object'):
  y4_train, _ = pd.factorize(y4_train)
if(y4_test.dtype == 'object'):
  y4_test, _ = pd.factorize(y4_test)


categorical_x_train_m_2_1 = x5_train.select_dtypes(include="object")
for i in categorical_x_train_m_2_1:
  x5_train[i] = pd.factorize(x5_train[i])[0]
categorical_x_test_m_2_1 = x5_test.select_dtypes(include="object")
for i in categorical_x_test_m_2_1:
  x5_test[i] = pd.factorize(x5_test[i])[0]
if(y5_train.dtype == 'object'):
  y5_train, _ = pd.factorize(y5_train)
if(y5_test.dtype == 'object'):
  y5_test, _ = pd.factorize(y5_test)

# %%
classifier_1 = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_1,predictions_1 = classifier_1.fit(x1_train, x1_test, y1_train, y1_test)
models_1.to_csv(output_path_l_1_1)
models_1
# Out:
#  97%|█████████▋| 30/31 [07:34<00:10, 10.76s/it]
# [LightGBM] [Info] Number of positive: 5230, number of negative: 58412
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003420 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1931
# [LightGBM] [Info] Number of data points in the train set: 63642, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.082178 -> initscore=-2.413110
# [LightGBM] [Info] Start training from score -2.413110
# 100%|██████████| 31/31 [07:34<00:00, 14.67s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.66               0.76     0.76      0.75
# Perceptron                         0.87               0.73     0.73      0.89
# BernoulliNB                        0.82               0.72     0.72      0.85
# GaussianNB                         0.87               0.70     0.70      0.89
# QuadraticDiscriminantAnalysis      0.90               0.66     0.66      0.90
# DecisionTreeClassifier             0.90               0.65     0.65      0.90
# PassiveAggressiveClassifier        0.90               0.64     0.64      0.90
# BaggingClassifier                  0.94               0.64     0.64      0.93
# LinearDiscriminantAnalysis         0.94               0.63     0.63      0.92
# LGBMClassifier                     0.94               0.63     0.63      0.93
# XGBClassifier                      0.94               0.62     0.62      0.93
# AdaBoostClassifier                 0.94               0.61     0.61      0.92
# LogisticRegression                 0.94               0.60     0.60      0.92
# CalibratedClassifierCV             0.94               0.60     0.60      0.92
# ExtraTreeClassifier                0.90               0.60     0.60      0.90
# RandomForestClassifier             0.94               0.60     0.60      0.92
# SVC                                0.94               0.60     0.60      0.92
# LabelPropagation                   0.91               0.60     0.60      0.90
# LabelSpreading                     0.91               0.60     0.60      0.90
# KNeighborsClassifier               0.93               0.59     0.59      0.91
# SGDClassifier                      0.94               0.58     0.58      0.92
# LinearSVC                          0.94               0.57     0.57      0.91
# ExtraTreesClassifier               0.94               0.56     0.56      0.91
# RidgeClassifierCV                  0.93               0.54     0.54      0.91
# RidgeClassifier                    0.93               0.54     0.54      0.91
# DummyClassifier                    0.93               0.50     0.50      0.89
#
#                                Time Taken
# Model
# NearestCentroid                      0.18
# Perceptron                           0.23
# BernoulliNB                          0.16
# GaussianNB                           0.14
# QuadraticDiscriminantAnalysis        0.28
# DecisionTreeClassifier               0.71
# PassiveAggressiveClassifier          0.20
# BaggingClassifier                    4.11
# LinearDiscriminantAnalysis           0.34
# LGBMClassifier                       0.68
# XGBClassifier                        2.40
# AdaBoostClassifier                   3.10
# LogisticRegression                   0.36
# CalibratedClassifierCV               1.82
# ExtraTreeClassifier                  0.17
# RandomForestClassifier               7.47
# SVC                                 73.19
# LabelPropagation                   155.55
# LabelSpreading                     194.15
# KNeighborsClassifier                 0.86
# SGDClassifier                        0.40
# LinearSVC                            0.60
# ExtraTreesClassifier                 6.86
# RidgeClassifierCV                    0.32
# RidgeClassifier                      0.16
# DummyClassifier                      0.10

# %%
classifier_2 = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_2,predictions_2 = classifier_2.fit(x2_train, x2_test, y2_train, y2_test)
models_2.to_csv(output_path_l_2_1)
models_2
# Out:
#  97%|█████████▋| 30/31 [44:47<04:04, 244.21s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005944 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1525
# [LightGBM] [Info] Number of data points in the train set: 92720, number of used features: 42
# [LightGBM] [Info] Start training from score -0.635705
# [LightGBM] [Info] Start training from score -1.019263
# [LightGBM] [Info] Start training from score -2.211126
# 100%|██████████| 31/31 [44:49<00:00, 86.76s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.48               0.42    None      0.47
# LGBMClassifier                     0.59               0.41    None      0.53
# XGBClassifier                      0.58               0.41    None      0.52
# RandomForestClassifier             0.58               0.40    None      0.52
# BaggingClassifier                  0.55               0.39    None      0.51
# ExtraTreesClassifier               0.57               0.39    None      0.51
# AdaBoostClassifier                 0.58               0.39    None      0.51
# BernoulliNB                        0.57               0.39    None      0.51
# Perceptron                         0.49               0.39    None      0.48
# SVC                                0.58               0.39    None      0.50
# GaussianNB                         0.53               0.39    None      0.43
# QuadraticDiscriminantAnalysis      0.49               0.38    None      0.43
# LogisticRegression                 0.57               0.38    None      0.49
# PassiveAggressiveClassifier        0.45               0.38    None      0.46
# DecisionTreeClassifier             0.48               0.38    None      0.47
# LinearDiscriminantAnalysis         0.56               0.38    None      0.47
# KNeighborsClassifier               0.53               0.37    None      0.49
# CalibratedClassifierCV             0.56               0.37    None      0.48
# LabelPropagation                   0.47               0.37    None      0.47
# LabelSpreading                     0.47               0.37    None      0.47
# LinearSVC                          0.56               0.37    None      0.47
# RidgeClassifier                    0.56               0.37    None      0.47
# RidgeClassifierCV                  0.56               0.37    None      0.47
# ExtraTreeClassifier                0.45               0.36    None      0.45
# SGDClassifier                      0.55               0.36    None      0.44
# DummyClassifier                    0.54               0.33    None      0.38
#
#                                Time Taken
# Model
# NearestCentroid                      0.25
# LGBMClassifier                       1.80
# XGBClassifier                        2.23
# RandomForestClassifier              19.85
# BaggingClassifier                    9.88
# ExtraTreesClassifier                17.29
# AdaBoostClassifier                   4.74
# BernoulliNB                          0.26
# Perceptron                           0.99
# SVC                               1844.65
# GaussianNB                           0.25
# QuadraticDiscriminantAnalysis        0.45
# LogisticRegression                   0.47
# PassiveAggressiveClassifier          0.70
# DecisionTreeClassifier               1.79
# LinearDiscriminantAnalysis           0.47
# KNeighborsClassifier                 1.44
# CalibratedClassifierCV               6.88
# LabelPropagation                   346.24
# LabelSpreading                     423.41
# LinearSVC                            1.50
# RidgeClassifier                      0.26
# RidgeClassifierCV                    0.54
# ExtraTreeClassifier                  0.38
# SGDClassifier                        2.30
# DummyClassifier                      0.19

# %%
classifier_4 = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_4,predictions_4 = classifier_4.fit(x4_train, x4_test, y4_train, y4_test)
models_4.to_csv(output_path_m_1_1)
models_4
# Out:
# 100%|██████████| 31/31 [00:00<00:00, 33.82it/s]
# [LightGBM] [Info] Number of positive: 55, number of negative: 53
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 105
# [LightGBM] [Info] Number of data points in the train set: 108, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.509259 -> initscore=0.037041
# [LightGBM] [Info] Start training from score 0.037041
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# KNeighborsClassifier               1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# QuadraticDiscriminantAnalysis      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# LogisticRegression                 1.00               1.00     1.00      1.00
# LabelPropagation                   0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.96               0.96     0.96      0.96
# RidgeClassifier                    0.96               0.96     0.96      0.96
# SVC                                0.96               0.96     0.96      0.96
# ExtraTreeClassifier                0.96               0.96     0.96      0.96
# CalibratedClassifierCV             0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# LinearDiscriminantAnalysis         0.96               0.96     0.96      0.96
# LinearSVC                          0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.92               0.92     0.92      0.92
# GaussianNB                         0.92               0.92     0.92      0.92
# PassiveAggressiveClassifier        0.92               0.92     0.92      0.92
# Perceptron                         0.88               0.88     0.88      0.87
# BernoulliNB                        0.79               0.79     0.79      0.79
# SGDClassifier                      0.75               0.75     0.75      0.74
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.11
# BaggingClassifier                    0.04
# DecisionTreeClassifier               0.01
# KNeighborsClassifier                 0.01
# ExtraTreesClassifier                 0.11
# XGBClassifier                        0.11
# LGBMClassifier                       0.09
# QuadraticDiscriminantAnalysis        0.01
# RandomForestClassifier               0.15
# LogisticRegression                   0.01
# LabelPropagation                     0.01
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.01
# SVC                                  0.01
# ExtraTreeClassifier                  0.01
# CalibratedClassifierCV               0.03
# LabelSpreading                       0.01
# LinearDiscriminantAnalysis           0.01
# LinearSVC                            0.01
# NuSVC                                0.01
# NearestCentroid                      0.01
# GaussianNB                           0.01
# PassiveAggressiveClassifier          0.01
# Perceptron                           0.01
# BernoulliNB                          0.01
# SGDClassifier                        0.01
# DummyClassifier                      0.01

# %%
classifier_5 = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models_5,predictions_5 = classifier_5.fit(x5_train, x5_test, y5_train, y5_test)
models_5.to_csv(output_path_m_2_1)
models_5
# Out:
# 100%|██████████| 31/31 [00:00<00:00, 35.43it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 78
# [LightGBM] [Info] Number of data points in the train set: 137, number of used features: 5
# [LightGBM] [Info] Start training from score -1.158781
# [LightGBM] [Info] Start training from score -1.182311
# [LightGBM] [Info] Start training from score -0.968737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier             0.71               0.71    None      0.71
# ExtraTreesClassifier               0.71               0.70    None      0.70
# LabelSpreading                     0.71               0.70    None      0.70
# RandomForestClassifier             0.71               0.70    None      0.70
# LabelPropagation                   0.71               0.70    None      0.70
# ExtraTreeClassifier                0.68               0.66    None      0.67
# BaggingClassifier                  0.65               0.63    None      0.63
# NuSVC                              0.61               0.61    None      0.59
# AdaBoostClassifier                 0.61               0.61    None      0.61
# GaussianNB                         0.58               0.58    None      0.58
# NearestCentroid                    0.58               0.58    None      0.58
# LinearDiscriminantAnalysis         0.58               0.58    None      0.58
# LGBMClassifier                     0.58               0.58    None      0.57
# CalibratedClassifierCV             0.55               0.56    None      0.55
# SVC                                0.55               0.55    None      0.54
# LogisticRegression                 0.55               0.55    None      0.55
# KNeighborsClassifier               0.55               0.55    None      0.52
# LinearSVC                          0.55               0.55    None      0.55
# RidgeClassifierCV                  0.55               0.55    None      0.55
# RidgeClassifier                    0.55               0.55    None      0.55
# BernoulliNB                        0.55               0.54    None      0.55
# QuadraticDiscriminantAnalysis      0.45               0.46    None      0.41
# Perceptron                         0.45               0.44    None      0.37
# PassiveAggressiveClassifier        0.39               0.38    None      0.38
# DummyClassifier                    0.29               0.33    None      0.13
# SGDClassifier                      0.32               0.32    None      0.32
#
#                                Time Taken
# Model
# DecisionTreeClassifier               0.01
# ExtraTreesClassifier                 0.11
# LabelSpreading                       0.01
# RandomForestClassifier               0.15
# LabelPropagation                     0.01
# ExtraTreeClassifier                  0.01
# BaggingClassifier                    0.03
# NuSVC                                0.01
# AdaBoostClassifier                   0.12
# GaussianNB                           0.01
# NearestCentroid                      0.01
# LinearDiscriminantAnalysis           0.01
# LGBMClassifier                       0.17
# CalibratedClassifierCV               0.04
# SVC                                  0.01
# LogisticRegression                   0.01
# KNeighborsClassifier                 0.01
# LinearSVC                            0.01
# RidgeClassifierCV                    0.01
# RidgeClassifier                      0.01
# BernoulliNB                          0.01
# QuadraticDiscriminantAnalysis        0.01
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.01
# DummyClassifier                      0.01
# SGDClassifier                        0.01
